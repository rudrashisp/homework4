# %%
import random, numpy as np
from matplotlib import pyplot
from numpy import meshgrid
random.seed(111)
X = [[random.randint(-40,40),random.randint(-40,40),1] for i in range(200)]
Y = [1 if i+3*j>2 else -1 for i,j,k in X]
xpos, xneg = [k for k in zip(*[i for i,j in zip(X,Y) if j==1])], [k for k in zip(*[i for i,j in zip(X,Y) if j==-1])]
print("count of 1(s) >>",Y.count(1),"| count of -1(s)>>",Y.count(-1))


def fn_delta(eta, epoch):
    W, acc_list,error_list= [random.random() for i in range(3)], [],[]
    delW=np.zeros(3)
    for i in range(epoch):
        o = np.matmul(X,W)
        delW=delW+eta*np.matmul((Y-o),X)
        W=np.add(W,delW)
        o = [1 if sum([i*j for i,j in zip(x,W)])>0 else -1 for x in X]
        acc = sum([i==j for i,j in zip(Y,o)])/len(X)
        print(i+1,'>> accuracy >> ',acc)
        acc_list += [acc]
        error_list +=[1-acc]
    t=[i+1 for i in range(epoch)]
    pyplot.plot(t,error_list)
    t=[i+1 for i in range(50)]
    pyplot.plot(t,error_list)
    pyplot.show()
    return o, acc_list, W

def fn_decision_boundary(wt):
    x1, x2 = range(-41,41), range(-41,41)
    z = [1 if i*wt[0]+j*wt[1]+wt[2]>0 else -1 for i in x1 for j in x2]
    xx, yy = meshgrid(x1, x2)
    zz = np.array(z).reshape(xx.shape)
    pyplot.contourf(xx, yy, zz, cmap='Paired')
    pyplot.scatter(xpos[0],xpos[1], cmap='Paired')
    pyplot.scatter(xneg[0],xneg[1], cmap='Paired')
    

pyplot.xlabel("number of epochs")
pyplot.ylabel("Train Error")
pyplot.title('25 Epochs Graph')
pred, acc, final_wt = fn_delta(eta = 0.01, epoch = 25)
fn_decision_boundary(final_wt)
# Out:
# count of 1(s) >> 102 | count of -1(s)>> 98
# 1 >> accuracy >>  0.01
# 2 >> accuracy >>  0.99
# 3 >> accuracy >>  0.01
# 4 >> accuracy >>  0.995
# 5 >> accuracy >>  0.005
# 6 >> accuracy >>  0.995
# 7 >> accuracy >>  0.005
# 8 >> accuracy >>  0.99
# 9 >> accuracy >>  0.01
# 10 >> accuracy >>  0.99
# 11 >> accuracy >>  0.01
# 12 >> accuracy >>  0.99
# 13 >> accuracy >>  0.01
# 14 >> accuracy >>  0.99
# 15 >> accuracy >>  0.015
# 16 >> accuracy >>  0.985
# 17 >> accuracy >>  0.015
# 18 >> accuracy >>  0.98
# 19 >> accuracy >>  0.02
# 20 >> accuracy >>  0.98
# 21 >> accuracy >>  0.02
# 22 >> accuracy >>  0.98
# 23 >> accuracy >>  0.02
# 24 >> accuracy >>  0.98
# 25 >> accuracy >>  0.02
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-82ca9a1b9a10> in <module>
#      41 pyplot.ylabel("Train Error")
#      42 pyplot.title('25 Epochs Graph')
# ...

# %%
    
pyplot.xlabel("number of epochs")
pyplot.ylabel("Train Error")
pyplot.title('50 Epochs at 0.1 learning rate')
pred, acc, final_wt = fn_delta(eta = 0.1, epoch = 50)
fn_decision_boundary(final_wt)
# Out:
# 1 >> accuracy >>  0.255
# 2 >> accuracy >>  0.77
# 3 >> accuracy >>  0.205
# 4 >> accuracy >>  0.81
# 5 >> accuracy >>  0.16
# 6 >> accuracy >>  0.845
# 7 >> accuracy >>  0.14
# 8 >> accuracy >>  0.88
# 9 >> accuracy >>  0.12
# 10 >> accuracy >>  0.885
# 11 >> accuracy >>  0.105
# 12 >> accuracy >>  0.91
# 13 >> accuracy >>  0.07
# 14 >> accuracy >>  0.93
# 15 >> accuracy >>  0.07
# 16 >> accuracy >>  0.93
# 17 >> accuracy >>  0.06
# 18 >> accuracy >>  0.94
# 19 >> accuracy >>  0.055
# 20 >> accuracy >>  0.95
# 21 >> accuracy >>  0.05
# 22 >> accuracy >>  0.95
# 23 >> accuracy >>  0.05
# 24 >> accuracy >>  0.95
# 25 >> accuracy >>  0.05
# 26 >> accuracy >>  0.95
# 27 >> accuracy >>  0.05
# 28 >> accuracy >>  0.95
# 29 >> accuracy >>  0.05
# 30 >> accuracy >>  0.955
# 31 >> accuracy >>  0.045
# 32 >> accuracy >>  0.955
# 33 >> accuracy >>  0.045
# 34 >> accuracy >>  0.955
# 35 >> accuracy >>  0.045
# 36 >> accuracy >>  0.955
# 37 >> accuracy >>  0.045
# 38 >> accuracy >>  0.955
# ...

# %%
pyplot.xlabel("number of epochs")
pyplot.ylabel("Train Error")
pyplot.title('50 Epochs at 0.01 learning rate')
pred, acc, final_wt = fn_delta(eta = 0.01, epoch = 50)
fn_decision_boundary(final_wt)
# Out:
# 1 >> accuracy >>  0.155
# 2 >> accuracy >>  0.88
# 3 >> accuracy >>  0.12
# 4 >> accuracy >>  0.885
# 5 >> accuracy >>  0.105
# 6 >> accuracy >>  0.9
# 7 >> accuracy >>  0.085
# 8 >> accuracy >>  0.93
# 9 >> accuracy >>  0.07
# 10 >> accuracy >>  0.93
# 11 >> accuracy >>  0.06
# 12 >> accuracy >>  0.94
# 13 >> accuracy >>  0.055
# 14 >> accuracy >>  0.945
# 15 >> accuracy >>  0.05
# 16 >> accuracy >>  0.95
# 17 >> accuracy >>  0.05
# 18 >> accuracy >>  0.95
# 19 >> accuracy >>  0.05
# 20 >> accuracy >>  0.95
# 21 >> accuracy >>  0.05
# 22 >> accuracy >>  0.95
# 23 >> accuracy >>  0.05
# 24 >> accuracy >>  0.955
# 25 >> accuracy >>  0.045
# 26 >> accuracy >>  0.955
# 27 >> accuracy >>  0.045
# 28 >> accuracy >>  0.955
# 29 >> accuracy >>  0.045
# 30 >> accuracy >>  0.955
# 31 >> accuracy >>  0.045
# 32 >> accuracy >>  0.955
# 33 >> accuracy >>  0.04
# 34 >> accuracy >>  0.96
# 35 >> accuracy >>  0.04
# 36 >> accuracy >>  0.96
# 37 >> accuracy >>  0.04
# 38 >> accuracy >>  0.96
# ...

# %%
pyplot.xlabel("number of epochs")
pyplot.ylabel("Train Error")
pyplot.title('50 Epochs at 0.001 learning rate')
pred, acc, final_wt = fn_delta(eta = 0.001, epoch = 50)
fn_decision_boundary(final_wt)
# Out:
# 1 >> accuracy >>  0.005
# 2 >> accuracy >>  0.995
# 3 >> accuracy >>  0.01
# 4 >> accuracy >>  0.99
# 5 >> accuracy >>  0.01
# 6 >> accuracy >>  0.99
# 7 >> accuracy >>  0.01
# 8 >> accuracy >>  0.99
# 9 >> accuracy >>  0.01
# 10 >> accuracy >>  0.985
# 11 >> accuracy >>  0.015
# 12 >> accuracy >>  0.985
# 13 >> accuracy >>  0.02
# 14 >> accuracy >>  0.98
# 15 >> accuracy >>  0.02
# 16 >> accuracy >>  0.98
# 17 >> accuracy >>  0.02
# 18 >> accuracy >>  0.98
# 19 >> accuracy >>  0.02
# 20 >> accuracy >>  0.98
# 21 >> accuracy >>  0.02
# 22 >> accuracy >>  0.98
# 23 >> accuracy >>  0.02
# 24 >> accuracy >>  0.98
# 25 >> accuracy >>  0.03
# 26 >> accuracy >>  0.97
# 27 >> accuracy >>  0.03
# 28 >> accuracy >>  0.97
# 29 >> accuracy >>  0.035
# 30 >> accuracy >>  0.965
# 31 >> accuracy >>  0.035
# 32 >> accuracy >>  0.965
# 33 >> accuracy >>  0.035
# 34 >> accuracy >>  0.965
# 35 >> accuracy >>  0.035
# 36 >> accuracy >>  0.965
# 37 >> accuracy >>  0.035
# 38 >> accuracy >>  0.965
# ...

# %%
pyplot.xlabel("number of epochs")
pyplot.ylabel("Train Error")
pyplot.title('50 Epochs at 0.0001 learning rate')
pred, acc, final_wt = fn_delta(eta = 0.0001, epoch = 50)
fn_decision_boundary(final_wt)
# Out:
# 1 >> accuracy >>  0.355
# 2 >> accuracy >>  0.665
# 3 >> accuracy >>  0.31
# 4 >> accuracy >>  0.71
# 5 >> accuracy >>  0.27
# 6 >> accuracy >>  0.765
# 7 >> accuracy >>  0.205
# 8 >> accuracy >>  0.82
# 9 >> accuracy >>  0.155
# 10 >> accuracy >>  0.85
# 11 >> accuracy >>  0.12
# 12 >> accuracy >>  0.88
# 13 >> accuracy >>  0.105
# 14 >> accuracy >>  0.91
# 15 >> accuracy >>  0.07
# 16 >> accuracy >>  0.93
# 17 >> accuracy >>  0.07
# 18 >> accuracy >>  0.94
# 19 >> accuracy >>  0.06
# 20 >> accuracy >>  0.945
# 21 >> accuracy >>  0.05
# 22 >> accuracy >>  0.95
# 23 >> accuracy >>  0.05
# 24 >> accuracy >>  0.95
# 25 >> accuracy >>  0.05
# 26 >> accuracy >>  0.95
# 27 >> accuracy >>  0.05
# 28 >> accuracy >>  0.95
# 29 >> accuracy >>  0.045
# 30 >> accuracy >>  0.955
# 31 >> accuracy >>  0.045
# 32 >> accuracy >>  0.955
# 33 >> accuracy >>  0.045
# 34 >> accuracy >>  0.955
# 35 >> accuracy >>  0.045
# 36 >> accuracy >>  0.96
# 37 >> accuracy >>  0.04
# 38 >> accuracy >>  0.96
# ...
